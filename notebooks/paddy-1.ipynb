# %%
from dotenv import load_dotenv
load_dotenv("/Users/paddy/Documents/Github/FretCoach/web/web-backend/.env")
from opik import Opik
opik_client = Opik()

# %%
TRACE_ID = '019c0341-e9d7-7cd0-8a34-c7ae57fbcab9' # UUIDv7 Identifier
trace_content = opik_client.get_trace_content(id = TRACE_ID)

# %%
trace_content.output['messages'][-2]['content']
# Out:
# '{\n  "success": true,\n  "data": [\n    {\n      "overall_avg_pitch": 0.736848384878821,\n      "overall_avg_timing": 0.705084593720249\n    }\n  ],\n  "row_count": 1\n}'

# %%
TRACE_ID = '019c0353-c8d5-7755-9ddb-ec9c26055860'
trace_content = opik_client.get_trace_content(id = TRACE_ID)

# %%
trace_content.output['messages'][-2]['content']
# Out:
# '{\n  "success": true,\n  "data": [\n    {\n      "start_timestamp": "2025-12-17T18:10:12",\n      "duration_seconds": 153.2,\n      "pitch_accuracy": 0.62,\n      "scale_conformity": 0.51,\n      "timing_stability": 0.48,\n      "total_notes_played": 180\n    },\n    {\n      "start_timestamp": "2025-12-17T18:20:01",\n      "duration_seconds": 333.0,\n      "pitch_accuracy": 0.71,\n      "scale_conformity": 0.58,\n      "timing_stability": 0.67,\n      "total_notes_played": 420\n    },\n    {\n      "start_timestamp": "2025-12-19T19:02:11",\n      "duration_seconds": 114.1,\n      "pitch_accuracy": 0.88,\n      "scale_conformity": 0.81,\n      "timing_stability": 0.79,\n      "total_notes_played": 95\n    },\n    {\n      "start_timestamp": "2025-12-19T19:10:45",\n      "duration_seconds": 444.0,\n      "pitch_accuracy": 0.54,\n      "scale_conformity": 0.39,\n      "timing_stability": 0.44,\n      "total_notes_played": 620\n    },\n    {\n      "start_timestamp": "2025-12-21T17:41:
# ...

# %%
TRACE_ID = '019c052d-991c-76c2-bda2-47d949f4e888'
trace_content = opik_client.get_trace_content(id = TRACE_ID)

# %%
trace_content.output['messages'][-1]['content']
# Out:
# [{'type': 'text',
# ...
