# %%
from dotenv import load_dotenv
load_dotenv("/Users/paddy/Documents/Github/FretCoach/web/web-backend/.env")
from opik import Opik
opik_client = Opik()

# %%
TRACE_ID = '019c0341-e9d7-7cd0-8a34-c7ae57fbcab9' # UUIDv7 Identifier
trace_content = opik_client.get_trace_content(id = TRACE_ID)
trace_content.output['messages'][-2]['content']

# %%
TRACE_ID = '019c0353-c8d5-7755-9ddb-ec9c26055860'
trace_content = opik_client.get_trace_content(id = TRACE_ID)
trace_content.output['messages'][-2]['content']

# %%
TRACE_ID = '019c052d-991c-76c2-bda2-47d949f4e888'
trace_content = opik_client.get_trace_content(id = TRACE_ID)

# %%
trace_content.output['messages'][-1]['content']
# Out:
# [{'type': 'text',
#   'text': "Here's a summary of your practice progress:\n\nYou have completed 85 practice sessions.\n\nYour performance metrics over time show some fluctuations. Let's look at the trends:\n\n*   **Pitch Accuracy:** Your pitch accuracy has varied, with scores ranging from 0% to 92%. Recently, you've had sessions with high accuracy (e.g., 90.8% and 92% on January 25, 2026), but also some lower ones.\n*   **Scale Conformity:** Your scale conformity also shows a wide range, from 0% to 86%. Similar to pitch accuracy, there are recent highs (e.g., 73.2% on January 25, 2026) and some lower scores.\n*   **Timing Stability:** Your timing stability has generally been quite good, often above 70%, with recent highs up to 96%. There are a few instances of lower stability, but the overall trend appears positive.\n*   **Total Notes Played:** The number of notes you play per session varies significantly, from as few as 0 to as many as 2389. This suggests a mix of short, focused exercises and longer practice sessions.\n*   **Session Duration:** Your sessions range from very short (a few seconds) to longer ones (up to approximately 8.7 minutes).\n\n**Overall Insight:**\nYour recent sessions on January 25, 2026, show some excellent peaks in pitch accuracy, scale conformity, and timing stability. This indicates that you are capable of achieving high scores. The variations across sessions might suggest that you are practicing different types of exercises or scales, some of which are more challenging than others.\n\nTo give you more specific insights, we could look at the average of these metrics, or focus on your performance with specific scales.\n\nWould you like to explore your average performance, or perhaps focus on a particular aspect of your playing?",
#   'extras': {'signature': '...'}}]

# %% [markdown]
# ----

# %% [markdown]
# ### 30/01/2026

# %%
TRACE_ID = '019c0a63-5cbd-7521-bdd1-c48ad7cb196b'
trace_content = opik_client.get_trace_content(id = TRACE_ID)

# %%
trace_content.input['input'][0]['content']
# Out:
# 'You are an AI guitar coach. Based on the practice history below, recommend a practice session.\n\nPRACTICE HISTORY:\n- Total sessions: 85\n- Average pitch accuracy: 73.7%\n- Average scale conformity: 46.3%\n- Average timing stability: 70.5%\n- Weakest area: scale\n\nRECENTLY PRACTICED SCALES:\n[\n  {\n    "scale_name": "G# Major",\n    "scale_type": "natural",\n    "times_practiced": 1,\n    "avg_pitch": 0.668316051318419,\n    "avg_scale": 0.328696770612688,\n    "avg_timing": 0.826643972232133,\n    "last_practiced": "2026-01-25T16:57:50.908036"\n  },\n  {\n    "scale_name": "G Major",\n    "scale_type": "natural",\n    "times_practiced": 11,\n    "avg_pitch": 0.769972340927571,\n    "avg_scale": 0.38787968778909,\n    "avg_timing": 0.676029565987235,\n    "last_practiced": "2026-01-25T16:55:35.352878"\n  },\n  {\n    "scale_name": "E Minor",\n    "scale_type": "pentatonic",\n    "times_practiced": 1,\n    "avg_pitch": 0.564121673313381,\n    "avg_scale": 0.189567811251064,\n    "avg_timing": 0.938404660234994,\n    "last_practiced": "2026-01-25T16:05:45.963340"\n  },\n  {\n    "scale_name": "D Minor",\n    "scale_type": "pentatonic",\n    "times_practiced": 1,\n    "avg_pitch": 0.691142352456399,\n    "avg_scale": 0.581831506184422,\n    "avg_timing": 0.952030824744169,\n    "last_practiced": "2026-01-25T16:02:58.165528"\n  },\n  {\n    "scale_name": "A Minor",\n    "scale_type": "pentatonic",\n    "times_practiced": 20,\n    "avg_pitch": 0.797211285580484,\n    "avg_scale": 0.544635719849089,\n    "avg_timing": 0.796678808978213,\n    "last_practiced": "2026-01-25T16:00:51.779113"\n  }\n]\n\nRECENT SESSIONS (last 10):\n[\n  {\n    "session_id": "6f6c8a97-1503-4210-8b8e-538035b44140",\n    "start_timestamp": "2026-01-25T16:57:50.908036",\n    "scale_chosen": "G# Major",\n    "scale_type": "natural",\n    "pitch_accuracy": 0.668316051318419,\n    "scale_conformity": 0.328696770612688,\n    "timing_stability": 0.826643972232133,\n    "total_notes_played": 540,\n    "correct_notes_played": 369,\n    "bad_notes_played": 171,\n    "duration_seconds": 90.061513,\n    "strictness": 0.5,\n    "sensitivity": 0.5\n  },\n  {\n    "session_id": "a465bf92-555d-43cb-97bd-636b5035c2ca",\n    "start_timestamp": "2026-01-25T16:55:35.352878",\n    "scale_chosen": "G Major",\n    "scale_type": "natural",\n    "pitch_accuracy": 0.83810608646607,\n    "scale_conformity": 0.443552542400093,\n    "timing_stability": 0.659637571043277,\n    "total_notes_played": 127,\n    "correct_notes_played": 120,\n    "bad_notes_played": 7,\n    "duration_seconds": 22.416325,\n    "strictness": 0.5,\n    "sensitivity": 0.5\n  },\n  {\n    "session_id": "6517c9df-7b13-4e16-9e05-d819b1dab45f",\n    "start_timestamp": "2026-01-25T16:52:55.757927",\n    "scale_chosen": "G Major",\n    "scale_type": "natural",\n    "pitch_accuracy": 0.920520415583338,\n    "scale_conformity": 0.442524283373088,\n    "timing_stability": 0.844643242444972,\n    "total_notes_played": 483,\n    "correct_notes_played": 379,\n    "bad_notes_played": 104,\n    "duration_seconds": 112.794504,\n    "strictness": 0.5,\n    "sensitivity": 0.5\n  },\n  {\n    "session_id": "6862dfb5-fbdf-454e-8315-c92395410f10",\n    "start_timestamp": "2026-01-25T16:50:54.192542",\n    "scale_chosen": "G Major",\n    "scale_type": "natural",\n    "pitch_accuracy": 0.885256848213104,\n    "scale_conformity": 0.598904978731042,\n    "timing_stability": 0.690481506002829,\n    "total_notes_played": 450,\n    "correct_notes_played": 357,\n    "bad_notes_played": 93,\n    "duration_seconds": 86.131234,\n    "strictness": 0.5,\n    "sensitivity": 0.5\n  },\n  {\n    "session_id": "7ecccb26-fa72-4b9b-846a-df396bb2fa01",\n    "start_timestamp": "2026-01-25T16:44:08.874913",\n    "scale_chosen": "G Major",\n    "scale_type": "natural",\n    "pitch_accuracy": 0.80868819484972,\n    "scale_conformity": 0.481779024262734,\n    "timing_stability": 0.807882383169718,\n    "total_notes_played": 889,\n    "correct_notes_pla ...

# %%
TRACE_ID = '019c0a76-5598-74ba-876a-31b8a6844338'
trace_content = opik_client.get_trace_content(id = TRACE_ID)

# %%
trace_content
# Out:
# TracePublic(id='019c0a76-5598-74ba-876a-31b8a6844338', project_id='019bfd9b-526d-74f8-9c68-94743589a0b1', name='ChatOpenAI', start_time=datetime.datetime(2026, 1, 29, 15, 54, 13, 272119, tzinfo=TzInfo(0)), end_time=datetime.datetime(2026, 1, 29, 15, 54, 14, 561508, tzinfo=TzInfo(0)), input={'messages': [[{'content': 'You are a direct guitar coach giving quick real-time feedback.\n\nYour feedback MUST be 1-2 sentences, maximum 30 words total.\n\nFormat: "[What\'s good], but [what\'s weak] - [specific actionable fix]"\n\nMetric interpretations and specific fixes:\n- Pitch Accuracy: How cleanly notes are fretted (low = finger pressure issues)\n  → Fix: "ease finger pressure" or "focus on clean fretting"\n\n- Scale Conformity: Playing correct scale notes across fretboard positions (low = stuck in one position or wrong notes)\n  → Fix: "explore positions 5-7" or "move up the fretboard" or "try higher positions now"\n\n- Timing Stability: Consistency of note spacing (low = rushing, dragging, uneven rhythm)\n  → Fix: "use a metronome" or "practice with metronome at 60 BPM" or "slow down and count"\n\nExamples:\n- "Timing is solid at 98%, but scale conformity at 73% means you\'re stuck. Move up to the 5th position now."\n- "Pitch is excellent and timing good, but scale conformity needs work. Explore different fretboard positions - try 7th and 9th frets."\n- "Great scale coverage, but timing stability is low at 45%. Practice with a metronome to build consistency."\n\nBe direct, conversational, and vary your wording. Maximum 30 words.', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'system', 'name': None, 'id': None}, {'content': "Metrics: Pitch 95%, Scale 60%, Timing 71%\nStrongest: Pitch Accuracy (95%)\nWeakest: Scale Conformity (60%)\n\nGive 1-2 sentences (max 30 words) - what's good, what's weak, specific actionable fix:", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': None}]]}, output={'generations': [[{'text': 'Pitch accuracy is impressive at 95%, but scale conformity is lacking at 60%. Try exploring higher positions on the fretboard to improve note variety.', 'generation_info': {'finish_reason': 'stop', 'logprobs': None}, 'type': 'ChatGeneration', 'message': {'lc': 1, 'type': 'constructor', 'id': ['langchain', 'schema', 'messages', 'AIMessage'], 'kwargs': {'content': 'Pitch accuracy is impressive at 95%, but scale conformity is lacking at 60%. Try exploring higher positions on the fretboard to improve note variety.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 30, 'prompt_tokens': 360, 'total_tokens': 390, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_3683ee3deb', 'id': 'chatcmpl-D3OdRHaON39D3vyCmjtGJ9DJhwikE', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'id': 'lc_run--019c0a76-5597-7221-b897-9abb68e27b9b-0', 'usage_metadata': {'input_tokens': 360, 'output_tokens': 30, 'total_tokens': 390, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}, 'tool_calls': [], 'invalid_tool_calls': []}}}]], 'llm_output': {'token_usage': {'completion_tokens': 30, 'prompt_tokens': 360, 'total_tokens': 390, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_3683ee3deb', 'id': 'chatcmpl-D3OdRHaON39D3vyCmjtGJ9DJhwikE', 'service_tier': 'default'}, 'run': None, 'type': 'LLMResult'}, metadata={'providers': ['openai'], 'session_id': '7544f52c-12b0-4d9a-aaff-f6893 ...

# %%
TRACE_ID = '019c0a76-cac9-748f-bca8-d9a621b36c43'
trace_content = opik_client.get_trace_content(id = TRACE_ID)

# %%
trace_content.output['generations'][0][0]['text']
# Out:
# 'Pitch accuracy is solid at 80%, but scale conformity is quite low at 43%. Focus on exploring positions 5-7 to improve your scale coverage.'
